# %%
import pandas as pd

# %%
df = pd.read_csv("test.csv")

# %%
df.plot(kind="bar", stacked = "true")
# Out:
#           Date                                         Task  \
# 0    4/05/2020                                         Test
# 1    4/05/2020       Electricity Show Demonstration Hunting
# 2    4/05/2020                                       Test 2
# 3    4/05/2020              Standardising Teacher Resources
# 4    4/05/2020                                  Get over it
# 5    4/05/2020                 Get Over It YouTube Playlist
# 6    4/05/2020                                   Mars Buggy
# 7    5/05/2020                                         Test
# 8    5/05/2020                                         Test
# 9    5/05/2020                                         Test
# 10   5/05/2020                                      Testing
# 11   5/05/2020                                         Test
# 12   5/05/2020                                         Test
# 13   5/05/2020                                         Test
# 14   5/05/2020                                         Test
# ...
